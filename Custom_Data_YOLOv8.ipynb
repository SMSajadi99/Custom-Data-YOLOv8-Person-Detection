# %% [markdown]
# <a href="https://colab.research.google.com/github/SMSajadi99/Custom-Data-YOLOv8-Person-Detection/blob/main/Custom_Data_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 8.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/SMSajadi99/Custom-Data-YOLOv8-Person-Detection.git
# Out:
# Cloning into 'Custom-Data-YOLOv8-Person-Detection'...
# remote: Enumerating objects: 46589, done.
# remote: Counting objects: 100% (15217/15217), done.
# remote: Compressing objects: 100% (13939/13939), done.
# remote: Total 46589 (delta 12), reused 15209 (delta 8), pack-reused 31372
# Receiving objects: 100% (46589/46589), 1.41 GiB | 18.26 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# Updating files: 100% (38449/38449), done.

# %%
# !nvidia-smi
# Out:
# Fri Aug 18 08:15:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/Custom-Data-YOLOv8-Person-Detection/custom.yaml epochs=25 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 359MB/s]
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/last.pt" source="/content/Custom-Data-YOLOv8-Person-Detection/images/test/000043.jpg"
# Out:
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# image 1/1 /content/Custom-Data-YOLOv8-Person-Detection/images/test/000043.jpg: 352x640 36 Persons, 121.7ms
# Speed: 3.0ms preprocess, 121.7ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict3

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/last.pt" source="/content/Venic.mp4"
# Out:
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# video 1/1 (1/600) /content/Venic.mp4: 384x640 14 Persons, 133.0ms
# video 1/1 (2/600) /content/Venic.mp4: 384x640 15 Persons, 39.8ms
# video 1/1 (3/600) /content/Venic.mp4: 384x640 16 Persons, 39.8ms
# video 1/1 (4/600) /content/Venic.mp4: 384x640 15 Persons, 39.9ms
# video 1/1 (5/600) /content/Venic.mp4: 384x640 17 Persons, 39.8ms
# video 1/1 (6/600) /content/Venic.mp4: 384x640 17 Persons, 30.6ms
# video 1/1 (7/600) /content/Venic.mp4: 384x640 17 Persons, 27.2ms
# video 1/1 (8/600) /content/Venic.mp4: 384x640 17 Persons, 27.1ms
# video 1/1 (9/600) /content/Venic.mp4: 384x640 17 Persons, 26.1ms
# video 1/1 (10/600) /content/Venic.mp4: 384x640 16 Persons, 26.2ms
# video 1/1 (11/600) /content/Venic.mp4: 384x640 16 Persons, 19.3ms
# video 1/1 (12/600) /content/Venic.mp4: 384x640 16 Persons, 19.5ms
# ...

# %%
# !zip -r /content/runs/detect/train /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/019446.jpg (deflated 1%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/008012.jpg (deflated 1%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/004640.jpg (deflated 0%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/000826.jpg (deflated 0%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/016436.jpg (deflated 1%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/010062.jpg (deflated 0%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/006912.jpg (deflated 2%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/020057.jpg (deflated 0%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/007416.jpg (deflated 1%)
#   adding: content/Custom-Data-YOLOv8-Person-Detection/images/test/012417.jpg (deflated 1%)
# ...
